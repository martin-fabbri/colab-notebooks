# %% [markdown]
# <a href="https://colab.research.google.com/github/martin-fabbri/colab-notebooks/blob/master/recsys%5Cmerlin%5Cmovielens_merlin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Apr  2 04:13:32 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install nvtabular
# Out:
# Collecting nvtabular
#   Downloading nvtabular-0.11.0.tar.gz (3.1 MB)
#      |████████████████████████████████| 3.1 MB 14.0 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from nvtabular) (1.3.5)
# Requirement already satisfied: tensorflow-metadata>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from nvtabular) (1.7.0)
# Collecting dask==2021.11.2
#   Downloading dask-2021.11.2-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 70.4 MB/s
# Requirement already satisfied: tqdm>=4.0 in /usr/local/lib/python3.7/dist-packages (from nvtabular) (4.63.0)
# Collecting numba>=0.55.1
#   Downloading numba-0.55.1-1-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 78.3 MB/s
# Collecting distributed==2021.11.2
#   Downloading distributed-2021.11.2-py3-none-any.whl (802 kB)
#      |████████████████████████████████| 802 kB 87.9 MB/s
# Requirement already satisfied: pyarrow>=1.0 in /usr/local/lib/python3.7/dist-packages (from nvtabular) (6.0.1)
# Collecting merlin-core==0.1.1
#   Downloading merlin-core-0.1.1.tar.gz (119 kB)
#      |████████████████████████████████| 119 kB 107.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from nvtabular) (21.3)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from nvtabular) (3.17.3)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 76.4 MB/s
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from dask==2021.11.2->nvtabular) (1.3.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from dask==2021.11.2->nvtabular) (0.11.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from dask==2021.11.2->nvtabular) (3.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from distributed==2021.11.2->nvtabular) (2.11.3)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed==2021.11.2->nvtabular) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed==2021.11.2->nvtabular) (1.7.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed==2021.11.2->nvtabular) (2.1.0)
# Requirement already satisfied: tornado>=5 in /usr/local/lib/python3.7/dist-packages (from distributed==2021.11.2->nvtabular) (5.1.1)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed==2021.11.2->nvtabular) (5.4.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed==2021.11.2->nvtabular) (57.4.0)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed==2021.11.2->nvtabular) (7.1.2)
# Collecting cloudpickle>=1.1.1
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed==2021.11.2->nvtabular) (1.0.3)
# Collecting betterproto<2.0.0
#   Downloading betterproto-1.2.5.tar.gz (26 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting grpclib
#   Downloading grpclib-0.4.2.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 6.6 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting stringcase
#   Downloading stringcase-1.2.0.tar.gz (3.0 kB)
# Requirement already satisfied: numpy<1.22,>=1.18 in /usr/local/lib/python3.7/dist-packages (from numba>=0.55.1->nvtabular) (1.21.5)
# Collecting llvmlite<0.39,>=0.38.0rc1
#   Downloading llvmlite-0.38.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      |████████████████████████████████| 34.5 MB 1.4 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->nvtabular) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->nvtabular) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->nvtabular) (2018.9)
# Collecting locket
#   Downloading locket-0.2.1-py2.py3-none-any.whl (4.1 kB)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.0.0->nvtabular) (1.15.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-metadata>=1.2.0->nvtabular) (1.56.0)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /usr/local/lib/python3.7/dist-packages (from tensorflow-metadata>=1.2.0->nvtabular) (1.0.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed==2021.11.2->nvtabular) (1.0.1)
# Collecting multidict
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.7 MB/s
# Collecting h2<5,>=3.1.0
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 6.9 MB/s
# Collecting hpack<5,>=4.0
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Collecting hyperframe<7,>=6.0
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->distributed==2021.11.2->nvtabular) (2.0.1)
# Building wheels for collected packages: nvtabular, merlin-core, betterproto, grpclib, stringcase
#   Building wheel for nvtabular (PEP 517) ... done
#   Created wheel for nvtabular: filename=nvtabular-0.11.0-cp37-cp37m-linux_x86_64.whl size=405388 sha256=4b179a300a3bfe7acd80195ec42d6edd1b262c2a14354e84bed3d65125857eed
#   Stored in directory: /root/.cache/pip/wheels/ec/bb/1e/751dcc73c05fb697d33965fdffb8443d2760b2ffa9fa6234b9
#   Building wheel for merlin-core (PEP 517) ... done
#   Created wheel for merlin-core: filename=merlin_core-0.1.1-py3-none-any.whl size=124360 sha256=fa64f8d2d3aa27235c9f55ba810f772af723d56cb09b1a6ba799dd15e7769b1e
#   Stored in directory: /root/.cache/pip/wheels/35/1a/94/3153abeb359cf19193e4dd477e62c76257ac4759cfe0a42114
#   Building wheel for betterproto (PEP 517) ... done
#   Created wheel for betterproto: filename=betterproto-1.2.5-py3-none-any.whl size=22013 sha256=44051e99e2b7f09d3ee3490a8b9cc3c81647430f960c86928b935029723c4c0e
#   Stored in directory: /root/.cache/pip/wheels/d5/d7/46/97b7ec73d54fb8fc70775837af159e34b4965eda3481c7e659
#   Building wheel for grpclib (PEP 517) ... done
#   Created wheel for grpclib: filename=grpclib-0.4.2-py3-none-any.whl size=70602 sha256=31761f8e914bb40d9122742a31e71c62cc6cc1a28792794de9be474bdf3c6022
#   Stored in directory: /root/.cache/pip/wheels/04/5a/87/85aaf11c595b636cada52ccdca3f2ccb9bf38f64c80193ba1b
#   Building wheel for stringcase (setup.py) ... done
#   Created wheel for stringcase: filename=stringcase-1.2.0-py3-none-any.whl size=3587 sha256=23f08b9c030197ab467ac1ed8978216af53099149f98447d9101acbdcd6b4693
#   Stored in directory: /root/.cache/pip/wheels/86/ab/a3/a8fa7e0a07e80f547e03468c03827f8257f7339327986faed1
# Successfully built nvtabular merlin-core betterproto grpclib stringcase
# Installing collected packages: locket, hyperframe, hpack, partd, multidict, h2, fsspec, cloudpickle, stringcase, llvmlite, grpclib, dask, numba, distributed, betterproto, merlin-core, nvtabular
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: dask
#     Found existing installation: dask 2.12.0
#     Uninstalling dask-2.12.0:
#       Successfully uninstalled dask-2.12.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
#   Attempting uninstall: distributed
#     Found existing installation: distributed 1.25.3
#     Uninstalling distributed-1.25.3:
#       Successfully uninstalled distributed-1.25.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.0.0 which is incompatible.
# Successfully installed betterproto-1.2.5 cloudpickle-2.0.0 dask-2021.11.2 distributed-2021.11.2 fsspec-2022.3.0 grpclib-0.4.2 h2-4.1.0 hpack-4.0.0 hyperframe-6.0.1 llvmlite-0.38.0 locket-0.2.1 merlin-core-0.1.1 multidict-6.0.2 numba-0.55.1 nvtabular-0.11.0 partd-1.2.0 stringcase-1.2.0

# %%
# External dependencies
import os

from merlin.core.utils import download_file

# Get dataframe library - cudf or pandas
from merlin.core.dispatch import get_lib
df_lib = get_lib()

# %%
INPUT_DATA_DIR = os.environ.get(
    "INPUT_DATA_DIR", os.path.expanduser("/content/movielens/data/")
)

# %%
download_file(
    "http://files.grouplens.org/datasets/movielens/ml-25m.zip",
    os.path.join(INPUT_DATA_DIR, "ml-25m.zip"),
)
# Out:
# downloading ml-25m.zip: 262MB [00:09, 26.7MB/s]
# unzipping files: 100%|██████████| 8/8 [00:06<00:00,  1.18files/s]

# %%
movies = df_lib.read_csv(os.path.join(INPUT_DATA_DIR, "ml-25m/movies.csv"))
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies["genres"] = movies["genres"].str.split("|")
movies = movies.drop("title", axis=1)
movies.head()
# Out:
#    movieId                                             genres
# 0        1  [Adventure, Animation, Children, Comedy, Fantasy]
# 1        2                     [Adventure, Children, Fantasy]
# 2        3                                  [Comedy, Romance]
# 3        4                           [Comedy, Drama, Romance]
# 4        5                                           [Comedy]

# %%
movies.to_parquet(os.path.join(INPUT_DATA_DIR, "movies_converted.parquet"))

# %%
ratings = df_lib.read_csv(os.path.join(INPUT_DATA_DIR, "ml-25m", "ratings.csv"))
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
ratings = ratings.drop("timestamp", axis=1)

# shuffle the dataset
ratings = ratings.sample(len(ratings), replace=False)

# split the train_df as training and validation data sets.
num_valid = int(len(ratings) * 0.2)

train = ratings[:-num_valid]
valid = ratings[-num_valid:]

# %%
train.to_parquet(os.path.join(INPUT_DATA_DIR, "train.parquet"))
valid.to_parquet(os.path.join(INPUT_DATA_DIR, "valid.parquet"))
