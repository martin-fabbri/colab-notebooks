# %% [markdown]
# # NLP Course 2 Week 1 Lesson : Building The Model - Lecture Exercise 01
# Estimated Time: 10 minutes
# <br>
# # Vocabulary Creation
# Create a tiny vocabulary from a tiny corpus
# <br>
# It's time to start small !
# <br>
# ### Imports and Data

# %%
# imports
import re # regular expression library; for tokenization of words
from collections import Counter # collections library; counter: dict subclass for counting hashable objects
import matplotlib.pyplot as plt # for data visualization

# %%
# the tiny corpus of text ! 
text = 'red pink pink blue blue yellow purple purple ORANGE BLUE BLUE PINK' # 🌈
print(text)
print('string length : ',len(text))
# Out:
# red pink pink blue blue yellow purple purple ORANGE BLUE BLUE PINK
# string length :  66

# %% [markdown]
# ### Preprocessing

# %%
# convert all letters to lower case
text_lowercase = text.lower()
print(text_lowercase)
print("string length:", len(text_lowercase))
# Out:
# red pink pink blue blue yellow purple purple orange blue blue pink
# string length: 66

# %%
words = re.findall(r"\w+", text_lowercase)
print(words)
print("count:", len(words))
# Out:
# ['red', 'pink', 'pink', 'blue', 'blue', 'yellow', 'purple', 'purple', 'orange', 'blue', 'blue', 'pink']
# count: 12

# %% [markdown]
# Create Vocabulary

# %%
vocab = set(words)
print(vocab)
print("count:", len(vocab))
# Out:
# {'blue', 'pink', 'red', 'orange', 'purple', 'yellow'}
# count: 6

# %% [markdown]
# ### Add Information with Word Counts
# Option 2 : Two alternatives for including the word count as well

# %%
counts_a = dict()
for w in words:
    counts_a[w] = counts_a.get(w, 0) + 1

print(counts_a)
print("count:", len(counts_a))
# Out:
# {'red': 1, 'pink': 3, 'blue': 4, 'yellow': 1, 'purple': 2, 'orange': 1}
# count: 6

# %%
counts_b = Counter(words)
print(counts_b)
print('count : ',len(counts_b))
# Out:
# Counter({'blue': 4, 'pink': 3, 'purple': 2, 'red': 1, 'yellow': 1, 'orange': 1})
# count :  6

# %%
d = {
    "blue": counts_b["blue"],
    "pink": counts_b["pink"],
    "purple": counts_b["purple"],
    "red": counts_b["red"],
    "yellow": counts_b["yellow"],
    "orange": counts_b["orange"],
}
plt.bar(range(len(d)), list(d.values()), align="center", color=d.keys())
_ = plt.xticks(range(len(d)), list(d.keys()))

# %% [markdown]
# ### Ungraded Exercise
# Note that `counts_b`, above, returned by `collections.Counter` is sorted by word count
#
# Can you modify the tiny corpus of ***text*** so that a new color appears
# between ***pink*** and ***red*** in `counts_b` ?
#
# Do you need to run all the cells again, or just specific ones ?

# %%
print('counts_b : ', counts_b)
print('count : ', len(counts_b))
# Out:
# counts_b :  Counter({'blue': 4, 'pink': 3, 'purple': 2, 'red': 1, 'yellow': 1, 'orange': 1})
# count :  6
