// %% [markdown]
// # TensorFlow.js on Colab

// %%
#@title ## Setup JavaScript Kernel
#@markdown This cell will install ``ijavascript`` a Javascript kernel 
#@markdown Jupyter notebooks. 

#@markdown ---
#@markdown **IMPORTANT:** Once the installation is completed, you must reload 
#@markdown this page in order to apply the changes.
#@markdown 
#@markdown Press ``F5`` to reload this page.
#@markdown 
#@markdown ---

%%shell
npm install -g npm@latest -q

# !npm install -g npm@latest -q
# !npm cache verify -q
# !npm install -g --unsafe-perm ijavascript -q
# !ijsinstall --install=global
# !jupyter-kernelspec list
// Out:
// ERROR! Session/line number was not unique in database. History logging moved to new session 61
// /tools/node/bin/npm -> /tools/node/lib/node_modules/npm/bin/npm-cli.js
// /tools/node/bin/npx -> /tools/node/lib/node_modules/npm/bin/npx-cli.js
// + npm@6.14.4
// updated 1 package in 7.109s
// Cache verified and compressed (~/.npm/_cacache):
// Content verified: 206 (22717561 bytes)
// Index entries: 273
// Finished in 0.682s
// /tools/node/bin/ijs -> /tools/node/lib/node_modules/ijavascript/bin/ijavascript.js
// /tools/node/bin/ijsconsole -> /tools/node/lib/node_modules/ijavascript/bin/ijsconsole.js
// /tools/node/bin/ijsinstall -> /tools/node/lib/node_modules/ijavascript/bin/ijsinstall.js
// /tools/node/bin/ijskernel -> /tools/node/lib/node_modules/ijavascript/lib/kernel.js
// /tools/node/bin/ijsnotebook -> /tools/node/lib/node_modules/ijavascript/bin/ijsnotebook.js
// + ijavascript@5.2.0
// updated 1 package in 2.021s
// Available kernels:
// ...

// %%
var { spawn } = require('child_process');
var sh = (cmd) => { 
    $$.async();
    var sp = spawn(cmd, { cwd: process.cwd(), stdio: 'pipe', shell: true, encoding: 'utf-8' });
    sp.stdout.on('data', data => console.log(data.toString()));
    sp.stderr.on('data', data => console.error(data.toString()));
    sp.on('close', () => $$.done());
};
var run_async = async (pf) => {
  $$.async();
  await pf();
  $$.done();
};
sh('npm init -y');
// Out:
//   File "<ipython-input-4-9c368944b455>", line 1
//     var { spawn } = require('child_process');
//         ^
// SyntaxError: invalid syntax
// ERROR! Session/line number was not unique in database. History logging moved to new session 64

// %%
!npm install -g npm@latest
!npm cache verify
!npm install -g --unsafe-perm ijavascript
!ijsinstall --install=global
!jupyter-kernelspec list
// Out:
// ERROR! Session/line number was not unique in database. History logging moved to new session 63
// /tools/node/bin/npm -> /tools/node/lib/node_modules/npm/bin/npm-cli.js
// /tools/node/bin/npx -> /tools/node/lib/node_modules/npm/bin/npx-cli.js
// + npm@6.14.4
// updated 1 package in 6.8s
// Cache verified and compressed (~/.npm/_cacache):
// Content verified: 206 (22717561 bytes)
// Index entries: 273
// Finished in 0.665s
// /tools/node/bin/ijsconsole -> /tools/node/lib/node_modules/ijavascript/bin/ijsconsole.js
// /tools/node/bin/ijsinstall -> /tools/node/lib/node_modules/ijavascript/bin/ijsinstall.js
// /tools/node/bin/ijskernel -> /tools/node/lib/node_modules/ijavascript/lib/kernel.js
// /tools/node/bin/ijsnotebook -> /tools/node/lib/node_modules/ijavascript/bin/ijsnotebook.js
// /tools/node/bin/ijs -> /tools/node/lib/node_modules/ijavascript/bin/ijavascript.js
// + ijavascript@5.2.0
// updated 1 package in 1.935s
// Available kernels:
// ...

// %%
var { spawn } = require('child_process');
var sh = (cmd) => { 
    $$.async();
    var sp = spawn(cmd, { cwd: process.cwd(), stdio: 'pipe', shell: true, encoding: 'utf-8' });
    sp.stdout.on('data', data => console.log(data.toString()));
    sp.stderr.on('data', data => console.error(data.toString()));
    sp.on('close', () => $$.done());
};
var run_async = async (pf) => {
  $$.async();
  await pf();
  $$.done();
};
sh('npm init -y');
// Out:
//   File "<ipython-input-4-9c368944b455>", line 1
//     var { spawn } = require('child_process');
//         ^
// SyntaxError: invalid syntax
