# %%
import numpy as np
import pandas as pd
import dask.array as da
import dask.dataframe as dd

# %%
images = np.ones((100, 1000, 1000))
print(f'No problem handling {np.prod(images.shape)} integer numbers.')
# Out:
# No problem handling 100000000 integer numbers.

# %%
try: 
    images = np.ones((10000, 1000, 1000))
    print('Impresive! No need for dask arrays.')
except:
    print('Unable to allocate an array with shape (10000, 1000, 1000)')
# Out:
# Unable to allocate an array with shape (10000, 1000, 1000)

# %%
try: 
    images = da.ones((10000, 1000, 1000))
    print('Dask arrays save the day!')
except:
    print('Dask arrays cannot to allocate an array with shape (10000, 1000, 1000)')

images
# Out:
# Dask arrays save the day!
# dask.array<ones, shape=(10000, 1000, 1000), dtype=float64, chunksize=(250, 250, 250), chunktype=numpy.ndarray>

# %%
df = dd.read_csv(
    'gcs://anaconda-public-data/nyc-taxi/csv/2015/yellow_*.csv'
).persist()
# Out:
# C:\Users\martin\Anaconda3\envs\uber\lib\site-packages\google\auth\_default.py:69: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
df.shape.compute()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-7869d5bb3e7f> in <module>
# ----> 1 df.shape.compute()
#
# AttributeError: 'tuple' object has no attribute 'compute'

# %%
df.describe().compute()
# Out:
#            VendorID  passenger_count  trip_distance  pickup_longitude  \
# count  1.461130e+08     1.461130e+08   1.461130e+08      1.461130e+08
# mean   1.524653e+00     1.680663e+00   1.313727e+01     -7.280689e+01
# std    4.993919e-01     1.333365e+00   1.987510e+04      9.220263e+00
# min    1.000000e+00     0.000000e+00  -4.084012e+07     -8.740026e+02
# 25%    1.000000e+00     1.000000e+00   1.200000e+00     -7.399049e+01
# 50%    2.000000e+00     1.000000e+00   2.110000e+00     -7.397923e+01
# 75%    2.000000e+00     2.000000e+00   3.960000e+00     -7.396299e+01
# max    2.000000e+00     9.000000e+00   1.986230e+08      1.726000e+02
#
#        pickup_latitude    RateCodeID  dropoff_longitude  dropoff_latitude  \
# count     1.461130e+08  1.461130e+08       1.461130e+08      1.461130e+08
# mean      4.010771e+01  1.042062e+00      -7.285360e+01      4.013439e+01
# std       5.078433e+00  6.680777e-01       9.039230e+00      4.979399e+00
# ...

# %%
df.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 19 entries, VendorID to total_amount
# dtypes: object(3), float64(12), int64(4)

# %%
df.passenger_count.value_counts().compute()
# Out:
# 1    102991045
# 2     20901372
# 5      7939001
# 3      6135107
# 6      5123951
# 4      2981071
# 0        40853
# 7          239
# 8          181
# 9          169
# Name: passenger_count, dtype: int64

# %%
taxi_fares_url = 'E:\\datasets\\new-york-city-taxi-fare-prediction\\train.csv'
df_taxi_fare = dd.read_csv(
    taxi_fares_url
).persist()

df_taxi_fare.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count
# 0                1
# 1                1
# 2                2
# ...

# %%
df_taxi_fare.passenger_count.value_counts().compute()
# Out:
# 1      38337524
# 2       8175243
# 5       3929346
# 3       2432712
# 4       1178852
# 6       1174647
# 0        195416
# 208          64
# 9            23
# 7            15
# 8             9
# 129           2
# 51            1
# 49            1
# 34            1
# Name: passenger_count, dtype: int64

# %%
pd.read_csv(taxi_fares_url)
# Out:
#                                     key  fare_amount          pickup_datetime  \
# 0           2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1           2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2          2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3           2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4         2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# ...                                 ...          ...                      ...
# 55423851   2014-03-15 03:28:00.00000070         14.0  2014-03-15 03:28:00 UTC
# 55423852    2009-03-24 20:46:20.0000002          4.2  2009-03-24 20:46:20 UTC
# 55423853    2011-04-02 22:04:24.0000004         14.1  2011-04-02 22:04:24 UTC
# 55423854    2011-10-26 05:57:51.0000002         28.9  2011-10-26 05:57:51 UTC
# 55423855   2014-12-12 11:33:00.00000015          7.5  2014-12-12 11:33:00 UTC
#
# ...

# %%
.passenger_count.value_counts()
