# %% [markdown]
# <a href="https://colab.research.google.com/github/martin-fabbri/colab-notebooks/blob/master/fastai_dlfc_v4/fastai_dlfc_v4_01_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-75e60560-979f-b558-2dfb-d16fd7674a4a)

# %%
# Mount to your Google Drive allowing lesson files will be saved to your Drive location
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/fastai/course-v4 'drive/My Drive/course-v4'
# Out:
# fatal: destination path 'drive/My Drive/course-v4' already exists and is not an empty directory.

# %%
# %cd drive/My\ Drive/course-v4
# Out:
# /content/drive/My Drive/course-v4

# %%
# !pip install -q -r requirements.txt
# Out:
#      |████████████████████████████████| 184kB 2.8MB/s
#      |████████████████████████████████| 51kB 7.5MB/s
#      |████████████████████████████████| 51kB 6.6MB/s
#      |████████████████████████████████| 1.0MB 8.6MB/s
#      |████████████████████████████████| 92kB 9.7MB/s
#      |████████████████████████████████| 40kB 6.3MB/s
#      |████████████████████████████████| 51kB 8.4MB/s
#      |████████████████████████████████| 61kB 8.4MB/s
#      |████████████████████████████████| 2.3MB 17.1MB/s

# %%
# %cd nbs
# Out:
# /content/drive/My Drive/course-v4/nbs

# %%
#hide
from utils import *

# %% [markdown]
# # Your deep learning journey

# %% [markdown]
# ## Deep learning is for everyone

# %% [markdown]
# ## Neural networks: a brief history

# %% [markdown]
# ## What you will learn

# %% [markdown]
# ## Who we are

# %% [markdown]
# ## How to learn deep learning

# %% [markdown]
# ### Your projects and your mindset

# %% [markdown]
# ## The software: PyTorch, fastai, and Jupyter (and why it doesn't matter)

# %% [markdown]
# ## Your first model

# %% [markdown]
# ### Getting a GPU deep learning server

# %% [markdown]
# ### Running your first notebook

# %%
# CLICK ME
from fastai2.vision.all import *
path = untar_data(URLs.PETS)/'images'

def is_cat(x): return x[0].isupper()
dls = ImageDataLoaders.from_name_func(
    path, get_image_files(path), valid_pct=0.2, seed=42,
    label_func=is_cat, item_tfms=Resize(224))

learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(IntProgress(value=0, max=87306240), HTML(value='')))
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.165379</td>
#       <td>0.031612</td>
#       <td>0.010825</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.065475</td>
#       <td>0.026383</td>
#       <td>0.009472</td>
#       <td>00:30</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Sidebar: This book was written in Jupyter Notebooks

# %%
from pathlib import Path
Path('abc')/'def'
# Out:
# PosixPath('abc/def')

# %%
img = PILImage.create('images/chapter1_cat_example.jpg')
img.to_thumb(192)
# Out:
# <PIL.Image.Image image mode=RGB size=151x192 at 0x7EFC97BC5BA8>

# %% [markdown]
# ### End sidebar

# %%
uploader = widgets.FileUpload()
uploader
# Out:
# FileUpload(value={}, description='Upload')
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/traitlets/traitlets.py in validate_elements(self, obj, value)
#    2251             try:
# -> 2252                 v = self._trait._validate(obj, v)
#    2253             except TraitError:
#
# /usr/local/lib/python3.6/dist-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#
# /usr/local/lib/python3.6/dist-packages/traitlets/traitlets.py in validate(self, obj, value)
#    2025             return value
# -> 2026         self.error(obj, value)
#    2027
#
# /usr/local/lib/python3.6/dist-packages/traitlets/traitlets.py in error(self, obj, value)
#     624                 % (self.name, self.info(), repr_type(value))
# --> 625         raise TraitError(e)
#     626
#
# TraitError: The 'None' trait of a FileUpload instance must be a bytes object, but a value of None <class 'NoneType'> was specified.
#
# During handling of the above exception, another exception occurred:
#
# TraitError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# /usr/local/lib/python3.6/dist-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# /usr/local/lib/python3.6/dist-packages/traitlets/traitlets.py in set_trait(self, name, value)
#    1341                                 (cls.__name__, name))
#    1342         else:
# -> 1343             getattr(cls, name).set(self, value)
#    1344
#    1345     @classmethod
#
# /usr/local/lib/python3.6/dist-packages/traitlets/traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# /usr/local/lib/python3.6/dist-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# /usr/local/lib/python3.6/dist-packages/traitlets/traitlets.py in validate(self, obj, value)
#    2322
#    2323     def validate(self, obj, value):
# -> 2324         value = super(List, self).validate(obj, value)
#    2325         value = self.validate_elements(obj, value)
#    2326         return value
#
# /usr/local/lib/python3.6/dist-packages/traitlets/traitlets.py in validate(self, obj, value)
#    2240             return value
#    2241
# -> 2242         value = self.validate_elements(obj, value)
#    2243
#    2244         return value
#
# /usr/local/lib/python3.6/dist-packages/traitlets/traitlets.py in validate_elements(self, obj, value)
#    2319             self.length_error(obj, value)
#    2320
# -> 2321         return super(List, self).validate_elements(obj, value)
#    2322
#    2323     def validate(self, obj, value):
#
# /usr/local/lib/python3.6/dist-packages/traitlets/traitlets.py in validate_elements(self, obj, value)
#    2252                 v = self._trait._validate(obj, v)
#    2253             except TraitError:
# -> 2254                 self.element_error(obj, v, self._trait)
#    2255             else:
#    2256                 validated.append(v)
#
# /usr/local/lib/python3.6/dist-packages/traitlets/traitlets.py in element_error(self, obj, element, validator)
#    2231         e = "Element of the '%s' trait of %s instance must be %s, but a value of %s was specified." \
#    2232             % (self.name, class_of(obj), validator.info(), repr_type(element))
# -> 2233         raise TraitError(e)
#    2234
#    2235     def validate(self, obj, value):
#
# TraitError: Element of the 'data' trait of a FileUpload instance must be a bytes object, but a value of None <class 'NoneType'> was specified.

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
uploader = SimpleNamespace(data = ['images/chapter1_cat_example.jpg'])

# %%
img = PILImage.create(uploader.data[0])
is_cat,_,probs = learn.predict(img)
print(f"Is this a cat?: {is_cat}.")
print(f"Probability it's a cat: {probs[1].item():.6f}")
# Out:
# Is this a cat?: True.
# Probability it's a cat: 1.000000

# %%
learn.show_results()

# %% [markdown]
# ### What is machine learning?

# %%
gv('''program[shape=box3d width=1 height=0.7]
inputs->program->results''')

# %%
gv('''model[shape=box3d width=1 height=0.7]
inputs->model->results; weights->model''')

# %%
gv('''ordering=in
model[shape=box3d width=1 height=0.7]
inputs->model->results; weights->model; results->performance
performance->weights[constraint=false label=update]''')

# %%
gv('''model[shape=box3d width=1 height=0.7]
inputs->model->results''')

# %% [markdown]
# ### What is a neural network?

# %% [markdown]
# #### A bit of deep learning jargon

# %%
gv('''ordering=in
model[shape=box3d width=1 height=0.7 label=architecture]
inputs->model->predictions; parameters->model; labels->loss; predictions->loss
loss->parameters[constraint=false label=update]''')

# %% [markdown]
# ### Limitations inherent to machine learning
#
# From this picture we can now see some fundamental things about training a deep learning model:
#
# - A model cannot be created without data ;
# - A model can only learn to operate on the patterns seen in the input data used to train it ;
# - This learning approach only creates *predictions*, not recommended *actions* ;
# - It's not enough to just have examples of input data; we need *labels* for that data too (e.g. pictures of dogs and cats aren't enough to train a model; we need a label for each one, saying which ones are dogs, and which are cats).
#
# Generally speaking, we've seen that most organizations that think they don't have enough data, actually mean they don't have enough *labeled* data. If any organization is interested in doing something in practice with a model, then presumably they have some inputs they plan to run their model against. And presumably they've been doing that some other way for a while (e.g. manually, or with some heuristic program), so they have data from those processes! For instance, a radiology practice will almost certainly have an archive of medical scans (since they need to be able to check how their patients are progressing over time), but those scans may not have structured labels containing a list of diagnoses or interventions (since radiologists generally create free text natural language reports, not structured data). We'll be discussing labeling approaches a lot in this book, since it's such an important issue in practice.
#
# Since these kinds of machine learning models can only make *predictions* (i.e. attempt to replicate labels), this can result in a significant gap between organizational goals and model capabilities. For instance, in this book you'll learn how to create a *recommendation system* that can predict what products a user might purchase. This is often used in e-commerce, such as to customize products shown on a home page, by showing the highest-ranked items. But such a model is generally created by looking at a user and their buying history (*inputs*) and what they went on to buy or look at (*labels*), which means that the model is likely to tell you about products they already have, or already know about, rather than new products that they are most likely to be interested in hearing about. That's very different to what, say, an expert at your local bookseller might do, where they ask questions to figure out your taste, and then tell you about authors or series that you've never heard of before.

# %% [markdown]
# ### How our image recognizer works

# %% [markdown]
# ### What our image recognizer learned

# %% [markdown]
# ### Image recognizers can tackle non-image tasks

# %% [markdown]
# ### Jargon recap

# %% [markdown]
# ## Deep learning is not just for image classification

# %%
path = untar_data(URLs.CAMVID_TINY)
dls = SegmentationDataLoaders.from_label_func(
    path, bs=8, fnames = get_image_files(path/"images"),
    label_func = lambda o: path/'labels'/f'{o.stem}_P{o.suffix}',
    codes = np.loadtxt(path/'codes.txt', dtype=str)
)

learn = unet_learner(dls, resnet34)
learn.fine_tune(8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.860964</td>
#       <td>2.098867</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.715837</td>
#       <td>1.557677</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.530387</td>
#       <td>1.215307</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.402190</td>
#       <td>1.072038</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.266924</td>
#       <td>0.859037</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.137657</td>
#       <td>0.714516</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.024289</td>
#       <td>0.672323</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.931822</td>
#       <td>0.652173</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.859505</td>
#       <td>0.637218</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results(max_n=6, figsize=(7,8))

# %%
from fastai2.text.all import *

dls = TextDataLoaders.from_folder(untar_data(URLs.IMDB), valid='test')
learn = text_classifier_learner(dls, AWD_LSTM, drop_mult=0.5, metrics=accuracy)
learn.fine_tune(4, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.589881</td>
#       <td>0.389701</td>
#       <td>0.825760</td>
#       <td>02:07</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.309843</td>
#       <td>0.311144</td>
#       <td>0.873600</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.212337</td>
#       <td>0.209378</td>
#       <td>0.916880</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.176842</td>
#       <td>0.193507</td>
#       <td>0.924520</td>
#       <td>04:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.143001</td>
#       <td>0.203519</td>
#       <td>0.925400</td>
#       <td>04:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.predict("I really liked that movie!")
# Out:
# ('pos', tensor(1), tensor([9.7168e-04, 9.9903e-01]))

# %% [markdown]
# ### Sidebar: The order matter

# %% [markdown]
# ### End sidebar

# %%
from fastai2.tabular.all import *
path = untar_data(URLs.ADULT_SAMPLE)

dls = TabularDataLoaders.from_csv(path/'adult.csv', path=path, 
                                  y_names="salary", 
                                  cat_names = ['workclass', 'education', 'marital-status', 'occupation','relationship', 'race'], 
                                  cont_names = ['age', 'fnlwgt', 'education-num'], 
                                  procs = [Categorify, FillMissing, Normalize])

learn = tabular_learner(dls, metrics=accuracy)

# %%
learn.fit_one_cycle(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.371163</td>
#       <td>0.361448</td>
#       <td>0.828778</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.343789</td>
#       <td>0.351141</td>
#       <td>0.839988</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.348971</td>
#       <td>0.347304</td>
#       <td>0.838606</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
from fastai2.collab import *
path = untar_data(URLs.ML_SAMPLE)
dls = CollabDataLoaders.from_csv(path/'ratings.csv')
learn = collab_learner(dls, y_range=(0.5,5.5))
learn.fine_tune(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.497096</td>
#       <td>1.402270</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.389329</td>
#       <td>1.346848</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.274070</td>
#       <td>1.175629</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.026271</td>
#       <td>0.891525</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.798628</td>
#       <td>0.767851</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.683477</td>
#       <td>0.741917</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.634295</td>
#       <td>0.732951</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.616413</td>
#       <td>0.728697</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.605462</td>
#       <td>0.726748</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.591847</td>
#       <td>0.726568</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.588841</td>
#       <td>0.726456</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userId</th>
#       <th>movieId</th>
#       <th>rating</th>
#       <th>rating_pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>89.0</td>
#       <td>43.0</td>
#       <td>4.0</td>
#       <td>3.653580</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>44.0</td>
#       <td>36.0</td>
#       <td>4.0</td>
#       <td>3.806760</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>85.0</td>
#       <td>79.0</td>
#       <td>4.5</td>
#       <td>4.547536</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>73.0</td>
#       <td>33.0</td>
#       <td>2.0</td>
#       <td>3.113232</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>86.0</td>
#       <td>38.0</td>
#       <td>4.0</td>
#       <td>4.013384</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>81.0</td>
#       <td>34.0</td>
#       <td>3.5</td>
#       <td>3.703192</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>44.0</td>
#       <td>26.0</td>
#       <td>4.5</td>
#       <td>3.926309</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>99.0</td>
#       <td>38.0</td>
#       <td>4.5</td>
#       <td>4.403430</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>94.0</td>
#       <td>58.0</td>
#       <td>4.0</td>
#       <td>3.906758</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Sidebar: Datasets: food for models

# %% [markdown]
# ### End sidebar

# %% [markdown]
# ## Validation sets and test sets

# %% [markdown]
# ### Use judgment in defining test sets

# %% [markdown]
# ## A _Choose Your Own Adventure_ moment

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# It can be hard to know in pages and pages of prose what are the key things you really need to focus on and remember. So we've prepared a list of questions and suggested steps to complete at the end of each chapter. All the answers are in the text of the chapter, so if you're not sure about anything here, re-read that part of the text and make sure you understand it. Answers to all these questions are also available on the [book website](https://book.fast.ai). You can also visit [the forums](https://forums.fast.ai) if you get stuck to get help from other folks studying this material.

# %% [markdown]
# 1. Do you need these for deep learning?
#    - Lots of math [F]
#    - Lots of data [F]
#    - Lots of expensive computers [F]
#    - A PhD [F]
# 1. Name five areas where deep learning is now the best in the world.
# 1. What was the name of the first device that was based on the principle of the artificial neuron?
# 1. Based on the book of the same name, what are the requirements for "Parallel Distributed Processing"?
# 1. What were the two theoretical misunderstandings that held back the field of neural networks?
# 1. What is a GPU?
# 1. Open a notebook and execute a cell containing: `1+1`. What happens?
# 1. Follow through each cell of the stripped version of the notebook for this chapter. Before executing each cell, guess what will happen.
# 1. Complete the Jupyter Notebook online appendix.
# 1. Why is it hard to use a traditional computer program to recognize images in a photo?
# 1. What did Samuel mean by "Weight Assignment"?
# 1. What term do we normally use in deep learning for what Samuel called "Weights"?
# > Parameters
# 1. Draw a picture that summarizes Arthur Samuel's view of a machine learning model
# 1. What is machine learning?
# > Machine learning is the training of programs developed by allowing computers to learn from it's experience, rather than manually coding individual steps.
# 1. Why is it hard to understand why a deep learning model makes a particular prediction?
# 1. What is the name of the theorem that a neural network can solve any mathematical problem to any level of accuracy?
# 1. What do you need in order to train a model?
# > Data, Labels(if training a supervised model), Model's architecture.
# 1. How could a feedback loop impact the rollout of a predictive policing model?
# >In the case of a positive feedback loop, the more the model is used, the more biased the data becomes making the model more biased. If a model doesn't balance between exploration and explotation, the model will be biased towards the highly ranked results, making less likely to include new unseen or less popular data on the results.
#
# 1. Do we always have to use 224x224 pixel images with the cat recognition model?
# > No 224x224 is the standard size for historical reasons (old pretrained models require this resolution). However, this resolution could be larger often resulting in better results (at the cost of increasing the memory footprint and processing). Smaller resulutions could lead to decremental precisions.
#
# 1. What is the difference between classification and regression?
# >* Classification tries to predict a class(category) among a discrete set of classes.
# >* Regression tries to predict one or more values.
#
# 1. What is a validation set? What is a test set? Why do we need them?
# > The validation set is used to measure the accuracy of a model.
#
# 1. What will fastai do if you don't provide a validation set?
# > It will by default select a random hold out set equivalent to a 20% of the training data.
#
# 1. Can we always use a random sample for a validation set? Why or why not?
# > It's not required to define a ramdon seed to select the same validation set between training runs. However, defining a random seed will help us to compare our models as we tune different settings.
#
# 1. What is overfitting? Provide an example.
# > Offerfitting occurs with a model attempts to memorize the training set; rather than finding generazible underying patterns in the data.
# > Overfitting should be only used when a model is actually overfitting during training. Applying any overfitting method to a model with enough data or not risking overfitting could endup huring the model's accuracy.
# 1. What is a metric? How does it differ to "loss"?
# > A metric is a function that measures the quality of your model's prediction using the validation set.
# > Loss vs. metric. Loss is defined to measure the performance that the training system could use to update weights automaticaly. In other words, a good choice for loss is a choice that is easy for stochastic descent to use.
# > Metrics are user oriented. A good metric it's easy to understand, it's intuitive and clearly conveys the model's prediction quality.
# > If you train a model for too long, not enough data, you will see the accuracy of the model to start get worse.
#
# 1. How can pretrained models help?
# > Pretrained models are helpful because they make your model very capable, even
# without needing to see any of your data. These model transfer many capabilities
# that your model would leverage regarless of any of your particular requirements. These capabilities include: edge, gradient or color detection; which are needed for many tasks.
#
# 1. What is the "head" of a model?
# > When using a pretrained model, cnn_learner will remove the last layer, since that is always specifically customized to the original training task, and replace it with one of more new layers with randomized weights. This last part
# os the model is known as `head`.
#
# 1. What kinds of features do the early layers of a CNN find? How about the later layers?
# > Layer 1 is able to detect diagonal, horizontal and vertical edges, as well as different gradients.
# > Layer 2 detects features such as corners, repeating lines, circles and other simple patterns. These are build from the basic building blocks established on Layer 1.
# > Layer 3 is able to identify higher levels semantic entities such as wheels, test, flower petals, etc.
# > Layer 4 and upper levels are able to build more complex semantic entities based on the building block defined on previous layers.
#
# 1. Are image models only useful for photos?
# 1. What is an "architecture"?
# > The functional form of a model it is called architecture.
# 1. What is segmentation?
# 1. What is `y_range` used for? When do we need it?
# 1. What are "hyperparameters"?
# 1. What's the best way to avoid failures when using AI in an organization?
# 1. What's transfer learning?
# > Transfer learning is the practice of using a pretrained model for a task different to what it was originally trained for.
#
# 1. What's fine tunning?
# > Fine tunning is a technique where teh parameters of a pretrained model are updated by training for additional epochs using a different task used for pretraining.

# %% [markdown]
# ### Further research

# %% [markdown]
# Each chapter also has a "further research" with questions that aren't fully answered in the text, or include more advanced assignments. Answers to these questions aren't on the book website--you'll need to do your own research!

# %% [markdown]
# 1. Why is a GPU useful for deep learning? How is a CPU different, and why is it less effective for deep learning?
# 1. Try to think of three areas where feedback loops might impact use of machine learning. See if you can find documented examples of that happening in practice.
